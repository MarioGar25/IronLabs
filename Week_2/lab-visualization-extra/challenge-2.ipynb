# %% [markdown]
# # Challenge 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('data/titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
titanic.select_dtypes(["float64"])
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# ...        ...        ...       ...
# 1304       NaN  29.513190    8.0500
# 1305       NaN  39.000000  108.9000
# 1306       NaN  38.500000    7.2500
# 1307       NaN  29.513190    8.0500
# 1308       NaN  25.315435   22.3583
#
# [1309 rows x 3 columns]

# %%
titanic.select_dtypes(["int64", "object"])
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.style.use("classic")
plt.rcParams["figure.figsize"] = [12.0, 6.0]

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
sns.histplot(x = "Age", data = titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
plt.subplot(3, 1, 1) # (rows, columns, panel number)
plt.plot((titanic["Age"][:11]))
plt.subplot(3, 1, 2)
plt.plot((titanic["Age"][:21]))
plt.subplot(3, 1, 3)
plt.plot((titanic["Age"][:51]))

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# It does affect, because the larger the sample the less detailed the subjects are, but at the same time the less representative the sample is of the total population. In addition, the larger the sample, the better you can see different behaviors. Even so, each of the plots is useful to answer certain questions we may have regarding the data.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
sns.histplot(x = "Age", data = titanic, color="Green")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
sns.countplot(x="Gender", data = titanic)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
titanic["Gender"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
sns.countplot(x="Pclass", data = titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
sns.boxplot(y="Age", data = titanic)
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %% [markdown]
# En esta grafica podemos ver donde se encuentra la mediana, algo menos que del valor 30, representada por la línea dentro del rectángulo azul. Esto significa, que la mitad de las personas del Titanic tenían menos de 28-29 años y la otra mitad superaba esta edad. También observamos que el percentil 75 está situado antes de llegar al valor 40, por lo que la gente inferior a esta edad sumaba el 75%. y el percentil 25 situado por encima de los 20. Por lo que, la gran mayoría de las personas se encontraban entre los 20 y los 40 años.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
plot = sns.kdeplot(x=titanic["Age"], hue=titanic["Gender"])
plot.axvline(x=titanic["Age"].mean(), c="red", label="mean")
plot.axvline(x=titanic["Age"].dropna().median(), c="green", label="median")
plt.legend()

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# In this graph it is clearer how the age is distributed, and when adding the gender we can also see the higher number of men and women. We also see that the majority of people are concentrated between 20 and 40 years of age, as we saw in the boxplot. In addition, the graph for men has a steeper curve, suggesting a greater number of people in the same age range, while the curve for women is smoother, implying a greater age distribution.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
sns.scatterplot(x = titanic["Fare"], y = titanic["Age"])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %%
titanic.plot(kind="scatter", x="Fare", y="Age")
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
s = titanic.corr()
sns.heatmap(data = s, vmin = 0, vmax = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# According to the graph, they correlate more with the "SibSp" and "Parch"

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
sns.boxplot(x = "Pclass", y="Age", data = titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
titanic_f = sns.FacetGrid(data=titanic, col="Gender")
titanic_f.map_dataframe(sns.histplot, x="Age")
